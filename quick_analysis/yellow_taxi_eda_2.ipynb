# %% [markdown]
# ## Exploratory Data Analysis

# %%
from pyspark.sql.functions import *

# %%
df = spark.read.table("nyctaxi.02_silver.yellow_trips_enriched")

# %% [markdown]
# #### Analyzes which taxi vendor generates the highest total revenue

# %%
df.groupBy("vendor").\
    agg(round(sum("total_amount"),2).alias("total_revenue")).\
    orderBy("total_revenue", ascending=False).\
    limit(3).\
    display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor</th><th>total_revenue</th></tr></thead><tbody><tr><td>Curb Mobility, LLC</td><td>5.3199717405E8</td></tr><tr><td>Creative Mobile Technologies, LLC</td><td>1.3442623175E8</td></tr><tr><td>Helix</td><td>9139402.56</td></tr></tbody></table></div>

# %% [markdown]
# ##### Analyzes which taxi vendor generates the lowest total revenue

# %%
df.groupBy("vendor").\
    agg(round(sum("total_amount"),2).alias("total_revenue")).\
    orderBy("total_revenue").\
    limit(1).\
    display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor</th><th>total_revenue</th></tr></thead><tbody><tr><td>Myle Technologies Inc</td><td>650986.43</td></tr></tbody></table></div>

# %% [markdown]
# #### Identifies the most popular pickup boroughs by trip count

# %%
df.groupBy("pu_borough").\
    agg(count("*").alias("count_of_trips")).\
    orderBy("count_of_trips", ascending=False).\
    display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pu_borough</th><th>count_of_trips</th></tr></thead><tbody><tr><td>Manhattan</td><td>20993328</td></tr><tr><td>Queens</td><td>2422670</td></tr><tr><td>Brooklyn</td><td>965727</td></tr><tr><td>Bronx</td><td>203183</td></tr><tr><td>Unknown</td><td>35989</td></tr><tr><td>N/A</td><td>12390</td></tr><tr><td>EWR</td><td>3509</td></tr><tr><td>Staten Island</td><td>2411</td></tr></tbody></table></div>

# %% [markdown]
# #### Identifies the most common journeys

# %%
df.groupBy(concat("pu_borough", lit("-->"), "do_borough").alias("journey")).\
    agg(count("*").alias("count_of_trips")).\
    orderBy("count_of_trips", ascending=False).\
    display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>journey</th><th>count_of_trips</th></tr></thead><tbody><tr><td>Manhattan-->Manhattan</td><td>19451907</td></tr><tr><td>Queens-->Manhattan</td><td>1182163</td></tr><tr><td>Queens-->Queens</td><td>723646</td></tr><tr><td>Manhattan-->Queens</td><td>637200</td></tr><tr><td>Manhattan-->Brooklyn</td><td>617416</td></tr><tr><td>Brooklyn-->Brooklyn</td><td>491871</td></tr><tr><td>Queens-->Brooklyn</td><td>385083</td></tr><tr><td>Brooklyn-->Manhattan</td><td>327932</td></tr><tr><td>Manhattan-->Bronx</td><td>170816</td></tr><tr><td>Brooklyn-->Queens</td><td>119573</td></tr><tr><td>Bronx-->Manhattan</td><td>92230</td></tr><tr><td>Bronx-->Bronx</td><td>77587</td></tr><tr><td>Queens-->N/A</td><td>69878</td></tr><tr><td>Queens-->Bronx</td><td>55480</td></tr><tr><td>Manhattan-->N/A</td><td>43202</td></tr><tr><td>Manhattan-->EWR</td><td>42622</td></tr><tr><td>Manhattan-->Unknown</td><td>27067</td></tr><tr><td>Brooklyn-->Bronx</td><td>23001</td></tr><tr><td>Unknown-->Manhattan</td><td>17188</td></tr><tr><td>Bronx-->Queens</td><td>16574</td></tr><tr><td>Bronx-->Brooklyn</td><td>16297</td></tr><tr><td>Unknown-->Unknown</td><td>15400</td></tr><tr><td>N/A-->N/A</td><td>10049</td></tr><tr><td>EWR-->EWR</td><td>3266</td></tr><tr><td>Manhattan-->Staten Island</td><td>3098</td></tr><tr><td>Queens-->Staten Island</td><td>2761</td></tr><tr><td>Queens-->Unknown</td><td>1864</td></tr><tr><td>Unknown-->Queens</td><td>1807</td></tr><tr><td>Queens-->EWR</td><td>1795</td></tr><tr><td>Brooklyn-->N/A</td><td>1696</td></tr><tr><td>Staten Island-->Brooklyn</td><td>1219</td></tr><tr><td>Unknown-->Brooklyn</td><td>1123</td></tr><tr><td>Brooklyn-->Staten Island</td><td>1046</td></tr><tr><td>N/A-->EWR</td><td>933</td></tr><tr><td>N/A-->Manhattan</td><td>656</td></tr><tr><td>Staten Island-->Staten Island</td><td>650</td></tr><tr><td>N/A-->Queens</td><td>466</td></tr><tr><td>Bronx-->N/A</td><td>443</td></tr><tr><td>Staten Island-->Manhattan</td><td>413</td></tr><tr><td>Brooklyn-->EWR</td><td>345</td></tr><tr><td>Brooklyn-->Unknown</td><td>263</td></tr><tr><td>Unknown-->N/A</td><td>188</td></tr><tr><td>Unknown-->Bronx</td><td>168</td></tr><tr><td>EWR-->N/A</td><td>125</td></tr><tr><td>N/A-->Brooklyn</td><td>115</td></tr><tr><td>Unknown-->EWR</td><td>106</td></tr><tr><td>N/A-->Bronx</td><td>91</td></tr><tr><td>Staten Island-->Queens</td><td>88</td></tr><tr><td>EWR-->Manhattan</td><td>78</td></tr><tr><td>N/A-->Unknown</td><td>67</td></tr><tr><td>Bronx-->Unknown</td><td>37</td></tr><tr><td>Staten Island-->N/A</td><td>20</td></tr><tr><td>EWR-->Unknown</td><td>15</td></tr><tr><td>Staten Island-->Bronx</td><td>13</td></tr><tr><td>N/A-->Staten Island</td><td>13</td></tr><tr><td>EWR-->Brooklyn</td><td>11</td></tr><tr><td>Unknown-->Staten Island</td><td>9</td></tr><tr><td>Bronx-->Staten Island</td><td>8</td></tr><tr><td>Bronx-->EWR</td><td>7</td></tr><tr><td>EWR-->Queens</td><td>7</td></tr><tr><td>Staten Island-->EWR</td><td>7</td></tr><tr><td>EWR-->Staten Island</td><td>6</td></tr><tr><td>Staten Island-->Unknown</td><td>1</td></tr><tr><td>EWR-->Bronx</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# #### Time series chart showing the number of trips and total revenue per day

# %%
df_2 = spark.read.table("nyctaxi.03_gold.daily_trip_summary")

df_2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_date</th><th>total_trips</th><th>average_passengers</th><th>average_distance</th><th>average_fare_per_trip</th><th>max_fare</th><th>min_fare</th><th>total_revenue</th></tr></thead><tbody><tr><td>2025-10-17</td><td>153567</td><td>1.3</td><td>6.8</td><td>19.57</td><td>791.2</td><td>-750.0</td><td>4372376.15</td></tr><tr><td>2025-10-30</td><td>163577</td><td>1.2</td><td>8.2</td><td>15.89</td><td>872.4</td><td>-600.0</td><td>3985705.06</td></tr><tr><td>2025-10-14</td><td>139132</td><td>1.2</td><td>5.3</td><td>19.42</td><td>642.1</td><td>-642.1</td><td>3979696.85</td></tr><tr><td>2025-10-04</td><td>147729</td><td>1.4</td><td>6.2</td><td>18.05</td><td>700.0</td><td>-600.0</td><td>3800808.15</td></tr><tr><td>2025-10-22</td><td>146946</td><td>1.2</td><td>4.1</td><td>17.38</td><td>483.2</td><td>-396.4</td><td>3903963.92</td></tr><tr><td>2025-10-08</td><td>149074</td><td>1.2</td><td>5.5</td><td>18.89</td><td>525.0</td><td>-374.7</td><td>4158597.71</td></tr><tr><td>2025-11-01</td><td>183035</td><td>1.4</td><td>7.3</td><td>13.87