# %%
import os

# %%
# Define the path for the lookup directory
lookup_dir_path = "/Volumes/nyc_taxi/landing/data_sources/lookup"

# Create the directory if it doesn't exist yet
os.makedirs(lookup_dir_path, exist_ok=True)
