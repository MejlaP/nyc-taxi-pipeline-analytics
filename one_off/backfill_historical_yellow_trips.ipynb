# %%
import os # operating system

# %%
# Define the list of months we want to process
months = ["2025-07", "2025-08", "2025-09", "2025-10", "2025-11", "2025-12"]

# Loop through each month and create the directory structure
for month in months:
    # Construct the directory path dynamically for each month
    dir_path = f"/Volumes/nyctaxi/00_landing/data_sources/nyctaxi_yellow/{month}"
    
    # Create the directory if it doesn't exist yet
    os.makedirs(dir_path, exist_ok=True)
