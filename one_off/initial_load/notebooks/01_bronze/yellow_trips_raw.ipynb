# %%
from pyspark.sql.functions import current_timestamp

# %%
# 1. Load all raw parquet files from the landing zone
df = spark.read.format("parquet").load("/Volumes/nyctaxi/00_landing/data_sources/nyctaxi_yellow/*")

# %%
# 2. Add current_timestamp for processing time
df = df.withColumn("processed_timestamp", current_timestamp())

# %%
# 3. Save as a managed table (Overwrite mode will replace the table content)
df.write.mode("overwrite").saveAsTable("nyctaxi.01_bronze.yellow_trips_raw")
