# %%
import os

# %%
# NOTE: This script performs validation of the **NYC taxi zone lookup reference data** in the landing zone. It ensures data availability before downstream processing..

# %%
# Define the file path for the lookup table
file_path = "/Volumes/nyctaxi/00_landing/data_sources/lookup/taxi_zone_lookup.csv"

# Validate that the lookup file exists in the landing zone
# If the file is missing, we raise an error to halt the pipeline immediately
if not os.path.exists(file_path):
    raise FileNotFoundError(f"Lookup file not found at: {file_path}")

# If the file exists, we print a confirmation and the process continues
print(f"Lookup file validated successfully at: {file_path}")
# Out:
# Lookup file validated successfully at: /Volumes/nyctaxi/00_landing/data_sources/lookup/taxi_zone_lookup.csv
